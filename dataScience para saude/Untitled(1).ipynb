# %%
import pandas as pd

# %%
confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')

# %%
confirmed.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  11/16/22  11/17/22  11/18/22  \
# 0        0        0        0        0  ...    204820    204982    205009
# 1        0        0        0        0  ...    333215    333233    333233
# 2        0        0        0        0  ...    270981    270996    270996
# 3        0        0        0        0  ...     46824     46824     46824
# 4        0        0        0        0  ...    103131    103131    103131
#
#    11/19/22  11/20/22  11/21/22  11/22/22  11/23/22  11/24/22  11/25/22
# 0    205039    205146    205229    205324    205391    205506    205541
# 1    333246    333256    333257    333282    333293    333305    333316
# 2    271011    271023    271028    271035    271041    271050    271057
# 3     46824     46824     46824     46824     46824     46824     46824
# 4    103131    103131    103131    103131    104491    104491    104491
#
# [5 rows x 1043 columns]

# %%
deaths = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')

# %%
recovered = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %%
confirmed.sample(20)
# Out:
#     Province/State       Country/Region        Lat        Long  1/22/20  \
# 256            NaN  Trinidad and Tobago  10.691800  -61.222500        0
# 147            NaN              Iceland  64.963100  -19.020800        0
# 25             NaN               Belize  17.189900  -88.497600        0
# 65         Guangxi                China  23.829800  108.788100        2
# 68           Hebei                China  39.549000  116.130600        1
# 110            NaN              Ecuador  -1.831200  -78.183400        0
# 283            NaN              Vietnam  14.058324  108.277199        0
# 90        Xinjiang                China  41.112900   85.240100        0
# 125  New Caledonia               France -20.904305  165.618042        0
# 199   Sint Maarten          Netherlands  18.042500  -63.054800        0
# 72           Hubei                China  30.975600  112.270700      444
# 220            NaN              Romania  45.943200   24.966800        0
# 157            NaN               Jordan  31.240000   36.510000        0
# 104      Greenland              Denmark  71.706900  -42.604300        0
# 190            NaN           Montenegro  42.708678   19.374390        0
# 237            NaN      Solomon Islands  -9.645700  160.156200        0
# 251            NaN             Tanzania  -6.369028   34.888822        0
# 12      Queensland            Australia -27.469800  153.025100        0
# 118            NaN                 Fiji -17.713400  178.065000        0
# 8              NaN              Armenia  40.069100   45.038200        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  11/16/22  11/17/22  \
# 256        0        0        0        0        0  ...    185094    185094
# 147        0        0        0        0        0  ...    206803    206803
# 25         0        0        0        0        0  ...     68988     68988
# 65         5       23       23       36       46  ...      2350      2350
# 68         1        2        8       13       18  ...      2055      2055
# 110        0        0        0        0        0  ...   1009388   1009388
# 283        2        2        2        2        2  ...  11509975  11510484
# 90         2        2        3        4        5  ...      2237      2263
# 125        0        0        0        0        0  ...     74818     74818
# 199        0        0        0        0        0  ...     10943     10943
# 72       444      549      761     1058     1423  ...     68454     68460
# 220        0        0        0        0        0  ...   3292905   3293346
# 157        0        0        0        0        0  ...   1746997   1746997
# 104        0        0        0        0        0  ...     11971     11971
# 190        0        0        0        0        0  ...    283410    283443
# 237        0        0        0        0        0  ...     21884     21884
# 251        0        0        0        0        0  ...     40311     40311
# 12         0        0        0        0        0  ...   1673798   1683096
# 118        0        0        0        0        0  ...     68287     68307
# 8          0        0        0        0        0  ...    445513    445513
#
#      11/18/22  11/19/22  11/20/22  11/21/22  11/22/22  11/23/22  11/24/22  \
# 256    185094    185094    185094    185094    185237    185237    185237
# 147    206803    206803    206803    206803    206803    206803    206803
# 25      68988     68988     68988     68988     69012     69012     69012
# 65       2351      2357      2357      2357      2360      2361      2364
# 68       2057      2066      2068      2073      2073      2182      2182
# 110   1009388   1009388   1009388   1009388   1009958   1009958   1009958
# 283  11510919  11511178  11511452  11511822  11512138  11512684  11513173
# 90       2290      2320      2340      2358      2377      2396      2414
# 125     74818     74818     74818     74818     75122     75258     75258
# 199     10943     10943     10943     10943     10943     10949     10949
# 72      68463     68470     68478     68484     68493     68502     68511
# 220   3293742   3294065   3294232   3294447   3294447   3294447   3294447
# 157   1746997   1746997   1746997   1746997   1746997   1746997   1746997
# 104     11971     11971     11971     11971     11971     11971     11971
# 190    283468    283488    283500    283512    283536    283566    283586
# 237     24575     24575     24575     24575     24575     24575     24575
# 251     40311     40311     40311     40311     40471     40471     40471
# 12    1683096   1683096   1683096   1683096   1683096   1683096   1693178
# 118     68307     68307     68307     68307     68307     68307     68375
# 8      445513    445513    445513    445631    445631    445631    445631
#
#      11/25/22
# 256    185237
# 147    206803
# 25      69012
# 65       2366
# 68       2182
# 110   1009958
# 283  11513747
# 90       2455
# 125     75258
# 199     10949
# 72      68523
# 220   3294447
# 157   1746997
# 104     11971
# 190    283607
# 237     24575
# 251     40471
# 12    1693178
# 118     68375
# 8      445631
#
# [20 rows x 1043 columns]

# %%
confirmed.iloc[0]
# Out:
# Province/State            NaN
# Country/Region    Afghanistan
# Lat                  33.93911
# Long                67.709953
# 1/22/20                     0
#                      ...
# 11/21/22               205229
# 11/22/22               205324
# 11/23/22               205391
# 11/24/22               205506
# 11/25/22               205541
# Name: 0, Length: 1043, dtype: object

# %%
confirmed.set_index('Province/State').loc['Anhui']
# Out:
# Country/Region       China
# Lat                31.8257
# Long              117.2264
# 1/22/20                  1
# 1/23/20                  9
#                     ...
# 11/21/22              1566
# 11/22/22              1568
# 11/23/22              1570
# 11/24/22              1572
# 11/25/22              1578
# Name: Anhui, Length: 1042, dtype: object

# %%
confirmed_by_country = confirmed.groupby('Country/Region').sum()

# %%
confirmed_by_country.sample(10)
# Out:
#                       Lat        Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Germany         51.165691   10.451526        0        0        0        0
# Mauritania      21.007900  -10.940800        0        0        0        0
# Mauritius      -20.348404   57.552152        0        0        0        0
# Vietnam         14.058324  108.277199        0        2        2        2
# Antarctica     -71.949900   23.347000        0        0        0        0
# Czechia         49.817500   15.473000        0        0        0        0
# Spain           40.463667   -3.749220        0        0        0        0
# Hungary         47.162500   19.503300        0        0        0        0
# Iceland         64.963100  -19.020800        0        0        0        0
# Kuwait          29.311660   47.481766        0        0        0        0
#
#                 1/26/20  1/27/20  1/28/20  1/29/20  ...  11/16/22  11/17/22  \
# Country/Region                                      ...
# Germany               0        1        4        4  ...  36152490  36180077
# Mauritania            0        0        0        0  ...     63414     63414
# Mauritius             0        0        0        0  ...    268397    268397
# Vietnam               2        2        2        2  ...  11509975  11510484
# Antarctica            0        0        0        0  ...        11        11
# Czechia               0        0        0        0  ...   4166741   4167299
# Spain                 0        0        0        0  ...  13551539  13551539
# Hungary               0        0        0        0  ...   2157995   2157995
# Iceland               0        0        0        0  ...    206803    206803
# Kuwait                0        0        0        0  ...    662510    662510
#
#                 11/18/22  11/19/22  11/20/22  11/21/22  11/22/22  11/23/22  \
# Country/Region
# Germany         36205405  36205405  36205405  36247081  36280371  36318461
# Mauritania         63417     63418     63419     63419     63419     63419
# Mauritius         268397    268397    268397    268397    268397    271867
# Vietnam         11510919  11511178  11511452  11511822  11512138  11512684
# Antarctica            11        11        11        11        11        11
# Czechia          4167377   4167817   4167937   4168015   4168864   4169493
# Spain           13573721  13573721  13573721  13573721  13573721  13573721
# Hungary          2157995   2157995   2157995   2157995   2157995   2162093
# Iceland           206803    206803    206803    206803    206803    206803
# Kuwait            662510    662510    662510    662617    662617    662617
#
#                 11/24/22  11/25/22
# Country/Region
# Germany         36348477  36373164
# Mauritania         63419     63419
# Mauritius         271867    271867
# Vietnam         11513173  11513747
# Antarctica            11        11
# Czechia          4170021   4170566
# Spain           13573721  13595504
# Hungary          2162093   2162093
# Iceland           206803    206803
# Kuwait            662617    662617
#
# [10 rows x 1041 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10,5))
confirmed_by_country.loc['China'][2:].plot()
plt.title('Casos confirmados na China', size=16)
plt.xticks(size=12)
plt.yticks(size=12)
# Out:
# (array([-500000.,       0.,  500000., 1000000., 1500000., 2000000.,
#         2500000., 3000000., 3500000., 4000000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
new_cases_china = confirmed_by_country.loc['China'][2:].diff().dropna()

# %%
plt.figure(figsize=(10,5))
new_cases_china.plot()

plt.title('Novos casos na China', size=16)
plt.xticks(size=14)
plt.yticks(size=14)
# Out:
# (array([-10000.,      0.,  10000.,  20000.,  30000.,  40000.,  50000.,
#          60000.,  70000.,  80000.,  90000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
new_cases_china_2 = confirmed_by_country.loc['China'][2:43].diff()

# %%
plt.figure(figsize=(10,5))
new_cases_china_2.plot()

plt.title('Novos casos na China', size=16)
plt.xticks(size=14)
plt.yticks(size=14)
# Out:
# (array([-2000.,     0.,  2000.,  4000.,  6000.,  8000., 10000., 12000.,
#         14000., 16000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
last_date = "3/2/20"
confirmed_by_country[last_date]
# Out:
# Country/Region
# Afghanistan             5
# Albania                 0
# Algeria                 3
# Andorra                 1
# Angola                  0
#                        ..
# West Bank and Gaza      0
# Winter Olympics 2022    0
# Yemen                   0
# Zambia                  0
# Zimbabwe                0
# Name: 3/2/20, Length: 201, dtype: int64

# %%
plt.figure(figsize=(10,5))
confirmed_by_country[last_date].plot(kind='pie')

plt.title('Novos casos na China', size=16)
# Out:
# Text(0.5, 1.0, 'Novos casos na China')

# %%
plt.figure(figsize=(10,5))
confirmed_by_country[last_date].sort_values(ascending=False)[1:10].plot(kind='bar')

plt.title('Confirmados por pais', size=16)
plt.xticks(size=14)
plt.yticks(size=14)
# Out:
# (array([   0., 1000., 2000., 3000., 4000., 5000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
deaths[last_date]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 284    0
# 285    0
# 286    0
# 287    0
# 288    0
# Name: 3/2/20, Length: 289, dtype: int64

# %%
def latest_by_country(data):
    return data.groupby('Country/Region').sum()[last_date]

# %%
info = [latest_by_country(confirmed),
latest_by_country(deaths),
latest_by_country(recovered)]

# %%
display(latest_by_country(confirmed))
display(latest_by_country(deaths))
display(latest_by_country(recovered))
# Out:
# Country/Region
# Afghanistan             5
# Albania                 0
# Algeria                 3
# Andorra                 1
# Angola                  0
#                        ..
# West Bank and Gaza      0
# Winter Olympics 2022    0
# Yemen                   0
# Zambia                  0
# Zimbabwe                0
# Name: 3/2/20, Length: 201, dtype: int64
# Country/Region
# Afghanistan             0
# Albania                 0
# Algeria                 0
# Andorra                 0
# Angola                  0
#                        ..
# West Bank and Gaza      0
# Winter Olympics 2022    0
# Yemen                   0
# Zambia                  0
# Zimbabwe                0
# Name: 3/2/20, Length: 201, dtype: int64
# Country/Region
# Afghanistan             0
# Albania                 0
# Algeria                 0
# Andorra                 0
# Angola                  0
#                        ..
# West Bank and Gaza      0
# Winter Olympics 2022    0
# Yemen                   0
# Zambia                  0
# Zimbabwe                0
# Name: 3/2/20, Length: 201, dtype: int64

# %%
combined = pd.concat(info, axis=1)
combined.columns = ['Confirmed', 'Deaths', 'Recovered']
combined
# Out:
#                       Confirmed  Deaths  Recovered
# Country/Region
# Afghanistan                   5       0          0
# Albania                       0       0          0
# Algeria                       3       0          0
# Andorra                       1       0          0
# Angola                        0       0          0
# ...                         ...     ...        ...
# West Bank and Gaza            0       0          0
# Winter Olympics 2022          0       0          0
# Yemen                         0       0          0
# Zambia                        0       0          0
# Zimbabwe                      0       0          0
#
# [201 rows x 3 columns]

# %%
sum_up = combined.sum()
letality_rate_1 = sum_up.Deaths/sum_up.Confirmed
letality_rate_2 = sum_up.Deaths/(sum_up.Recovered + sum_up.Deaths)*100
print(letality_rate_1*100)
print(letality_rate_2*100)
# Out:
# 3.418822331880242
# 634.5620700277235

# %%
letality_rate_1 = combined.Deaths/combined.Confirmed *100
letality_rate_2 = combined.Deaths/(combined.Recovered + combined.Deaths) *100
combined['letality_rate_1'] = letality_rate_1
combined['letality_rate_2'] = letality_rate_2
combined.dropna().head()
# Out:
#                 Confirmed  Deaths  Recovered  letality_rate_1  letality_rate_2
# Country/Region
# Australia              30       1         11         3.333333         8.333333
# Belgium                 8       0          1         0.000000         0.000000
# Cambodia                1       0          1         0.000000         0.000000
# Canada                 45       0          6         0.000000         0.000000
# China               80136    2914      44854         3.636318         6.100318

# %%
combined.sort_values("letality_rate_1", ascending=False)
# Out:
#                       Confirmed  Deaths  Recovered  letality_rate_1  \
# Country/Region
# San Marino                    1       1          0       100.000000
# Philippines                   3       1          1        33.333333
# US                           55       6          7        10.909091
# Iran                       1501      66        291         4.397069
# China                     80136    2914      44854         3.636318
# ...                         ...     ...        ...              ...
# West Bank and Gaza            0       0          0              NaN
# Winter Olympics 2022          0       0          0              NaN
# Yemen                         0       0          0              NaN
# Zambia                        0       0          0              NaN
# Zimbabwe                      0       0          0              NaN
#
#                       letality_rate_2
# Country/Region
# San Marino                 100.000000
# Philippines                 50.000000
# US                          46.153846
# Iran                        18.487395
# China                        6.100318
# ...                               ...
# West Bank and Gaza                NaN
# Winter Olympics 2022              NaN
# Yemen                             NaN
# Zambia                            NaN
# Zimbabwe                          NaN
#
# [201 rows x 5 columns]

# %%
import seaborn as sns

# %%
sns.scatterplot(x=combined.Confirmed, y=combined.letality_rate_1)
# Out:
# <AxesSubplot:xlabel='Confirmed', ylabel='letality_rate_1'>

# %%
combined_filtered = combined.query('Confirmed > 40')

# %%
sns.scatterplot(x=combined_filtered.Confirmed, y=combined_filtered.letality_rate_1)
# Out:
# <AxesSubplot:xlabel='Confirmed', ylabel='letality_rate_1'>

# %%
sns.scatterplot(data = combined.query('Recovered > 40'), x='Confirmed', y='letality_rate_2')
# Out:
# <AxesSubplot:xlabel='Confirmed', ylabel='letality_rate_2'>

# %%
sns.distplot(combined.query('Confirmed > 40').letality_rate_1, kde=False, bins=10)
# Out:
# C:\Users\lucas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='letality_rate_1'>

# %%
combined.sort_values('letality_rate_1', ascending=False).query('Confirmed > 40').head(10)
# Out:
#                   Confirmed  Deaths  Recovered  letality_rate_1  \
# Country/Region
# US                       55       6          7        10.909091
# Iran                   1501      66        291         4.397069
# China                 80136    2914      44854         3.636318
# United Kingdom          134       4          8         2.985075
# Italy                  2036      52        149         2.554028
# Taiwan*                  41       1         12         2.439024
# Thailand                 43       1         31         2.325581
# Japan                   278       6         32         2.158273
# France                  191       3         12         1.570681
# Diamond Princess        705       6         10         0.851064
#
#                   letality_rate_2
# Country/Region
# US                      46.153846
# Iran                    18.487395
# China                    6.100318
# United Kingdom          33.333333
# Italy                   25.870647
# Taiwan*                  7.692308
# Thailand                 3.125000
# Japan                   15.789474
# France                  20.000000
# Diamond Princess        37.500000

# %%
combined.sort_values('letality_rate_2', ascending=False).query('Recovered > 40').head(10)
# Out:
#                 Confirmed  Deaths  Recovered  letality_rate_1  letality_rate_2
# Country/Region
# Italy                2036      52        149         2.554028        25.870647
# Iran                 1501      66        291         4.397069        18.487395
# China               80136    2914      44854         3.636318         6.100318
# Singapore             108       0         78         0.000000         0.000000

# %%
confirmed.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  11/16/22  11/17/22  11/18/22  \
# 0        0        0        0        0  ...    204820    204982    205009
# 1        0        0        0        0  ...    333215    333233    333233
# 2        0        0        0        0  ...    270981    270996    270996
# 3        0        0        0        0  ...     46824     46824     46824
# 4        0        0        0        0  ...    103131    103131    103131
#
#    11/19/22  11/20/22  11/21/22  11/22/22  11/23/22  11/24/22  11/25/22
# 0    205039    205146    205229    205324    205391    205506    205541
# 1    333246    333256    333257    333282    333293    333305    333316
# 2    271011    271023    271028    271035    271041    271050    271057
# 3     46824     46824     46824     46824     46824     46824     46824
# 4    103131    103131    103131    103131    104491    104491    104491
#
# [5 rows x 1043 columns]

# %%
def latest_by_country_at(data,date):
    return data.groupby('Country/Region').sum()[date]

# %%
info = [latest_by_country_at(confirmed, '2/20/20'),
latest_by_country_at(deaths, '2/20/20'),
latest_by_country_at(recovered, '2/20/20')]

# %%
combined_2 = pd.concat(info, axis=1)
combined_2.columns = ['Confirmed', 'Deaths', 'Recovered']

sum_up = combined_2.loc['China']
letality_rate_1 = sum_up.Deaths/sum_up.Confirmed
letality_rate_2 = sum_up.Deaths/(sum_up.Recovered + sum_up.Deaths)
print(letality_rate_1*100)
print(letality_rate_2*100)
# Out:
# 2.980939568709458
# 11.050760418724076

# %%
sum_up = combined_2.sum()
letality_rate_1 = sum_up.Deaths/sum_up.Confirmed
letality_rate_2 = sum_up.Deaths/(sum_up.Recovered + sum_up.Deaths)
print(letality_rate_1*100)
print(letality_rate_2*100)
# Out:
# 2.952136034428466
# 11.012676814644413

# %%
letality_rate_1 = combined.Deaths/combined.Confirmed *100
letality_rate_2 = combined.Deaths/(combined.Recovered + combined.Deaths) *100
combined['letality_rate_1'] = letality_rate_1
combined['letality_rate_2'] = letality_rate_2
combined.dropna().head()
# Out:
#                 Confirmed  Deaths  Recovered  letality_rate_1  letality_rate_2
# Country/Region
# Australia              30       1         11         3.333333         8.333333
# Belgium                 8       0          1         0.000000         0.000000
# Cambodia                1       0          1         0.000000         0.000000
# Canada                 45       0          6         0.000000         0.000000
# China               80136    2914      44854         3.636318         6.100318

# %%
info = [latest_by_country_at(confirmed, '2/8/20'),
latest_by_country_at(deaths, '2/20/20'),
latest_by_country_at(recovered, '2/20/20')]

combined_12 = pd.concat(info, axis=1)
combined_12.columns = ['Confirmed', 'Deaths', 'Recovered']

sum_up = combined_12.loc['China']
letality_rate = sum_up.Deaths/sum_up.Confirmed
print(letality_rate*100)
display(sum_up)
# Out:
# 6.079208996577389
# Confirmed    36814
# Deaths        2238
# Recovered    18014
# Name: China, dtype: int64

# %%
confirmed.set_index('Country/Region').loc['China'].sum().tail()
# Out:
# 11/21/22    3364415
# 11/22/22    3373507
# 11/23/22    3437108
# 11/24/22    3449676
# 11/25/22    3490482
# dtype: object

# %%
is_china = confirmed['Country/Region'] == 'China'

# %%
confirmed['is_china'] = is_china

# %%
confirmed.groupby('is_china').sum()['3/2/20'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='is_china'>

# %%
confirme_by_china = confirmed.groupby('is_china').sum()

# %%
import numpy as np

confirmed['is_china_label'] = np.where(confirmed['is_china'],'China', 'Others')

# %%
confirmed['is_china_label'].tail()
# Out:
# 284    Others
# 285    Others
# 286    Others
# 287    Others
# 288    Others
# Name: is_china_label, dtype: object

# %%
confirmed.groupby('is_china_label').sum()[last_date].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='3/2/20'>

# %%
confirmed.groupby('is_china_label').sum()[last_date].plot(kind='pie')
plt.title(f'Casos confirmados até {last_date}')
# Out:
# Text(0.5, 1.0, 'Casos confirmados até 3/2/20')

# %%
summed = confirmed.groupby('is_china_label').sum()
summed['delta'] = summed['3/2/20'] - summed['2/1/20']
summed['delta'].plot(kind='bar')

plt.title(f'Novos casos confirmados em {last_date}')
# Out:
# Text(0.5, 1.0, 'Novos casos confirmados em 3/2/20')

# %%
summed
# Out:
#                         Lat         Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# is_china_label
# China           1085.292300  3688.937700      548      643      920     1406
# Others          4573.979946  2677.320324        9       14       24       31
#
#                 1/26/20  1/27/20  1/28/20  1/29/20  ...   11/18/22   11/19/22  \
# is_china_label                                      ...
# China              2075     2877     5509     6087  ...    3242270    3295792
# Others               45       52       71       82  ...  634372601  634565762
#
#                  11/20/22   11/21/22   11/22/22   11/23/22   11/24/22  \
# is_china_label
# China             3329533    3364415    3373507    3437108    3449676
# Others          634753722  635074784  635642978  636158987  636923911
#
#                  11/25/22  is_china  delta
# is_china_label
# China             3490482        34  68245
# Others          637577316         0  10099
#
# [2 rows x 1043 columns]

# %%
summed.T[2:43].plot()
# Out:
# <AxesSubplot:>

# %%
differences = summed.T[2:43].diff()
differences.plot()
# Out:
# <AxesSubplot:>

# %%
cases = confirmed.groupby('is_china_label').sum()[last_date].loc['China']
estimated_population = 1437525528
incidence_ratio = cases/estimated_population
incidence_ratio * 100000
# Out:
# 5.574579264097771

# %%
population = pd.read_csv('population.csv')
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_3384\2045285175.py:1: DtypeWarning: Columns (2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   population = pd.read_csv('population.csv')

# %%
population.PopTotal = population.PopTotal*1000

# %%
population_test = population.groupby('Location').sum()

# %%
population_total = population.query('Time == 2019')[['Location', 'PopTotal']].set_index('Location')

# %%
combined.join(population_total)
# Out:
#                       Confirmed  Deaths  Recovered  letality_rate_1  \
# Country/Region
# Afghanistan                   5       0          0              0.0
# Albania                       0       0          0              NaN
# Algeria                       3       0          0              0.0
# Andorra                       1       0          0              0.0
# Angola                        0       0          0              NaN
# ...                         ...     ...        ...              ...
# West Bank and Gaza            0       0          0              NaN
# Winter Olympics 2022          0       0          0              NaN
# Yemen                         0       0          0              NaN
# Zambia                        0       0          0              NaN
# Zimbabwe                      0       0          0              NaN
#
#                       letality_rate_2  PopTotal
# Country/Region
# Afghanistan                       NaN       NaN
# Albania                           NaN       NaN
# Algeria                           NaN       NaN
# Andorra                           NaN       NaN
# Angola                            NaN       NaN
# ...                               ...       ...
# West Bank and Gaza                NaN       NaN
# Winter Olympics 2022              NaN       NaN
# Yemen                             NaN       NaN
# Zambia                            NaN       NaN
# Zimbabwe                          NaN       NaN
#
# [201 rows x 6 columns]

# %%
population.query('Location.str.contains("United States of America") and Time == 2019', engine='python')
# Out:
#         SortOrder  LocID Notes  ISO3_code  ISO2_code  SDMX_code  LocTypeID  \
# 175917        NaN   1111   NaN        NaN        NaN        NaN        NaN
#
#        LocTypeName  ParentID                                     Location  \
# 175917         NaN       NaN  United States of America (and dependencies)
#
#         VarID Variant    Time  MidPeriod     PopMale   PopFemale     PopTotal  \
# 175917    2.0  Medium  2019.0     2019.5  167442.399  170536.787  337979186.0
#
#         PopDensity
# 175917      36.906

# %%
combined.join(population_total).sort_values('Confirmed', ascending=False)
# Out:
#                   Confirmed  Deaths  Recovered  letality_rate_1  \
# Country/Region
# China                 80136    2914      44854         3.636318
# Korea, South           4335      28         30         0.645905
# Italy                  2036      52        149         2.554028
# Iran                   1501      66        291         4.397069
# Diamond Princess        705       6         10         0.851064
# ...                     ...     ...        ...              ...
# Lesotho                   0       0          0              NaN
# Liberia                   0       0          0              NaN
# Libya                     0       0          0              NaN
# Liechtenstein             0       0          0              NaN
# Zimbabwe                  0       0          0              NaN
#
#                   letality_rate_2  PopTotal
# Country/Region
# China                    6.100318       NaN
# Korea, South            48.275862       NaN
# Italy                   25.870647       NaN
# Iran                    18.487395       NaN
# Diamond Princess        37.500000       NaN
# ...                           ...       ...
# Lesotho                       NaN       NaN
# Liberia                       NaN       NaN
# Libya                         NaN       NaN
# Liechtenstein                 NaN       NaN
# Zimbabwe                      NaN       NaN
#
# [201 rows x 6 columns]

# %%
population.query("Location.str.contains('Korea')", engine='python')
# Out:
# Empty DataFrame
# Columns: [SortOrder, LocID, Notes, ISO3_code, ISO2_code, SDMX_code, LocTypeID, LocTypeName, ParentID, Location, VarID, Variant, Time, MidPeriod, PopMale, PopFemale, PopTotal, PopDensity]
# Index: []

# %%
def rename_location(location):
    if location == 'China (and dependencies)':
        return 'China'
    if location == 'Republic of Korea':
        return 'Korea, South'
    if location == 'Iran (Islamic Republic of)':
        return 'Iran'
    if location == 'United States of America (and dependencies)':
        return 'US'
    return location
population_total['location_for_who'] = population_total.index.map(rename_location)

# %% [raw]
# population_total.query("location_for_who =='China'")

# %%
population_total = population_total.set_index('location_for_who')
population_total.head()
# Out:
#                                    PopTotal
# location_for_who
# AUKUS                          4.264555e+08
# African Group                  1.325907e+09
# African Union                  1.326452e+09
# African Union: Central Africa  1.584814e+08
# African Union: Eastern Africa  3.846874e+08

# %%
combined_expanded = combined.join(population_total).sort_values('Confirmed', ascending=False).dropna()

# %%
combined_expanded
# Out:
#                 Confirmed  Deaths  Recovered  letality_rate_1  \
# Country/Region
# China               80136    2914      44854         3.636318
# US                     55       6          7        10.909091
#
#                 letality_rate_2      PopTotal
# Country/Region
# China                  6.100318  1.453802e+09
# US                    46.153846  3.379792e+08

# %%
combined_expanded['incidence_ratio'] = combined_expanded['Confirmed']/combined_expanded['PopTotal']*100000
combined_expanded['mortality_rate'] = combined_expanded['Deaths']/combined_expanded['PopTotal']*100000

# %%
combined_expanded
# Out:
#                 Confirmed  Deaths  Recovered  letality_rate_1  \
# Country/Region
# China               80136    2914      44854         3.636318
# US                     55       6          7        10.909091
#
#                 letality_rate_2      PopTotal  incidence_ratio  mortality_rate
# Country/Region
# China                  6.100318  1.453802e+09         5.512169        0.200440
# US                    46.153846  3.379792e+08         0.016273        0.001775
